# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Day11_Messy_Company_Employee_Dataset.csv")

print("Dataset loaded")
# Out:
# Dataset loaded

# %%
#to print first 5 rows
df.head()
# Out:
#   Employee_ID Employee_Name       Department          Job_Title   Age  Gender  \
# 0     EMP0098   Ananya Nair              NaN     Data Scientist  48.0   Other
# 1     EMP0046   Faizan Khan        Marketing  Marketing Manager  31.0  Female
# 2     EMP0017   Saira Malik  Human Resources         HR Manager  28.0  Female
# 3     EMP0105    Neha Menon      Engineering  Software Engineer  30.0  Female
# 4     EMP0143    Hiba Menon            Sales      Sales Manager  25.0  Female
#
#    Annual_Salary  Experience_Years Joining_Date       City  Performance_Score  \
# 0       108371.0              13.2   2017-06-13       Pune                5.0
# 1       108824.0              12.1   2021-09-15     Mumbai                2.0
# 2       119400.0              13.2   2021-02-05  Bengaluru                3.0
# 3       111847.0               NaN   2018-08-05     Jaipur                4.0
# 4        78677.0              10.9   2018-07-24  Hyderabad                4.0
#
#   Work_Mode
# 0    Office
# ...

# %%
#to print last 5 rows
df.tail()
# Out:
#     Employee_ID Employee_Name        Department                 Job_Title  \
# 152     EMP0132     Manya Rao         Marketing        Content Strategist
# 153     EMP0073  Karan Kapoor  Customer Success  Customer Success Manager
# 154     EMP0124  Saira Kapoor       Engineering               QA Engineer
# 155     EMP0020      Sara Ali             Sales           Sales Executive
# 156     EMP0120  Saira Sheikh         Marketing       Marketing Executive
#
#       Age  Gender  Annual_Salary  Experience_Years Joining_Date       City  \
# 152  30.0  Female        49522.0               0.6   2021-11-25      Delhi
# 153  42.0    MALE        43331.0               1.1   2018-03-23     Jaipur
# 154  33.0    Male        94812.0               7.2   2024-06-12     Jaipur
# 155  22.0  Female        51745.0               2.4   2020-11-19        NaN
# 156  52.0    Male       107328.0              17.4   2020-11-25  Bengaluru
#
#      Performance_Score Work_Mode
# 152                2.0    Remote
# ...

# %%
#to get random rows
df.sample(7)
# Out:
#     Employee_ID  Employee_Name        Department                 Job_Title  \
# 4       EMP0143     Hiba Menon             Sales             Sales Manager
# 51      EMP0007    Rohan Menon       Engineering  Senior Software Engineer
# 35      EMP0142       Diya Das         Marketing         Marketing Manager
# 119     EMP0112    Arjun Mehta  Customer Success        Support Specialist
# 138     EMP0067   Vivaan Joshi       Engineering  Senior Software Engineer
# 71      EMP0022  Kashish Gupta           Finance         Financial Analyst
# 137     EMP0008       Riya Rao         Marketing       Marketing Executive
#
#       Age  Gender  Annual_Salary  Experience_Years Joining_Date        City  \
# 4    25.0  Female        78677.0              10.9   2018-07-24   Hyderabad
# 51   24.0  Female        79669.0               4.2   2017-02-17       Delhi
# 35   43.0    Male            NaN               1.2   2021-03-02   Bengaluru
# ...

# %%
print("number of rows: ",df.shape[0])
print("number of cloumns: ",df.shape[1])
print("shape of dataset: ",df.shape)
# Out:
# number of rows:  157
# number of cloumns:  12
# shape of dataset:  (157, 12)

# %%
#to print columnn name
print(df.columns)
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Department', 'Job_Title', 'Age',
#        'Gender', 'Annual_Salary', 'Experience_Years', 'Joining_Date', 'City',
#        'Performance_Score', 'Work_Mode'],
#       dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
print(df.dtypes)
# Out:
# Employee_ID           object
# Employee_Name         object
# Department            object
# Job_Title             object
# Age                  float64
# Gender                object
# Annual_Salary        float64
# Experience_Years     float64
# Joining_Date          object
# City                  object
# Performance_Score    float64
# Work_Mode             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        157 non-null    object
#  1   Employee_Name      157 non-null    object
#  2   Department         152 non-null    object
#  3   Job_Title          157 non-null    object
#  4   Age                153 non-null    float64
#  5   Gender             152 non-null    object
#  6   Annual_Salary      152 non-null    float64
#  7   Experience_Years   154 non-null    float64
#  8   Joining_Date       157 non-null    object
#  9   City               152 non-null    object
#  10  Performance_Score  154 non-null    float64
#  11  Work_Mode          155 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 14.8+ KB

# %%
df.describe()
# Out:
#               Age  Annual_Salary  Experience_Years  Performance_Score
# count  153.000000     152.000000        154.000000         154.000000
# mean    38.130719   89240.592105          8.990909           3.525974
# std      9.361661   22626.172309          4.983874           0.930233
# min     21.000000   43331.000000          0.600000           2.000000
# 25%     30.000000   71198.500000          4.450000           3.000000
# 50%     39.000000   90046.500000          9.350000           4.000000
# 75%     46.000000  107328.000000         13.200000           4.000000
# max     52.000000  162942.000000         17.400000           5.000000

# %%
df.describe(include="all")
# Out:
#        Employee_ID Employee_Name Department       Job_Title         Age  \
# count          157           157        152             157  153.000000
# unique         150           130         10              23         NaN
# top        EMP0075    Nikhil Das  Marketing  Data Scientist         NaN
# freq             2             3         23              13         NaN
# mean           NaN           NaN        NaN             NaN   38.130719
# std            NaN           NaN        NaN             NaN    9.361661
# min            NaN           NaN        NaN             NaN   21.000000
# 25%            NaN           NaN        NaN             NaN   30.000000
# 50%            NaN           NaN        NaN             NaN   39.000000
# 75%            NaN           NaN        NaN             NaN   46.000000
# max            NaN           NaN        NaN             NaN   52.000000
#
#        Gender  Annual_Salary  Experience_Years Joining_Date        City  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID          0
# Employee_Name        0
# Department           5
# Job_Title            0
# Age                  4
# Gender               5
# Annual_Salary        5
# Experience_Years     3
# Joining_Date         0
# City                 5
# Performance_Score    3
# Work_Mode            2
# dtype: int64
